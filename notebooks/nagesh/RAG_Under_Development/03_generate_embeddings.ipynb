# %% [markdown]
# Now we move to AI Engineering
# Create a new notebook:
#
# This notebook will only generate embeddings.
#
# It should not:
#
# build FAISS
# query vectors
# call an LLM
# create the chatbot
#
# It has one responsibility:
#
# Chunked Documents
#         │
#         ▼
# Embeddings
#         │
#         ▼
# Save to S3
# Notebook 03 Structure
#
# We will implement it in this order:
#
# 1. Read chunked parquet
#
# 2. Load embedding model
#
# 3. Generate embeddings
#
# 4. Store embeddings
#
# 5. Validate embeddings
#
# Nothing more.

# %% [markdown]
# Notebook 03 – Generate Embeddings
#
# We'll build this notebook in small, testable steps.
#
# 03_generate_embeddings.ipynb
#
# 1. Read chunked parquet
# 2. Load embedding model
# 3. Test embedding on one chunk
# 4. Generate embeddings
# 5. Save embeddings to S3
# 6. Validate output

# %%
#Step 1 – Install Required Libraries
# %pip install sentence-transformers
# %pip install torch
# %pip install pyarrow
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>User</th><th>Current session?</th></tr><tr><td>2</td><td>application_1785250991557_0003</td><td>pyspark</td><td>idle</td><td><a target="_blank" href="http://ip-172-31-32-154.ec2.internal:20888/proxy/application_1785250991557_0003/">Link</a></td><td><a target="_blank" href="http://ip-172-31-32-244.ec2.internal:8042/node/containerlogs/container_1785250991557_0003_01_000001/livy">Link</a></td><td>None</td><td>✔</td></tr></table>
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# SparkSession available as 'spark'.
# FloatProgress(value=0.0, bar_style='info', description='Progress:', layout=Layout(height='25px', width='50%'),…
# An error was encountered:
# unknown magic command 'pip'
# UnknownMagic: unknown magic command 'pip'
